# %% [markdown]
# Conexão de Google Collab com Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Clone da aplicação Yolo para usar no treino do algoritmo.

# %%
! git clone https://github.com/ultralytics/yolov5.git
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %% [markdown]
# Instalação dos requirimentos python para execução do Yolo.

# %%
! pip install -r yolov5/requirements.txt

# %% [markdown]
# Caminho da pasta que se encontra o arquivo .yaml, necessário para mostrar os caminhos da pasta de treino e validação.

# %%
cp /content/drive/MyDrive/training-ia-test/barco/barco.yaml yolov5/data/

# %% [markdown]
# Treino do algoritmo onde se pode fazer configuração de épocas, porem fundamental cuidado na alteração a elevação no numero das épocas pois pode trazer um overfitting.

# %%
# !python yolov5/train.py --data barco.yaml --weights yolov5s.pt --img 640 --epochs 40
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-10-12 23:29:36.490531: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760311776.510218   45305 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760311776.516176   45305 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1760311776.531260   45305 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
import os
import subprocess

def get_latest_train_run_folder():
    subfolders = [f.path for f in os.scandir('yolov5/runs/train') if f.is_dir()]
    latest_folder = max(subfolders, key=os.path.getctime, default=None)
    return latest_folder

latest_run = get_latest_train_run_folder()
result = subprocess.run(f'python yolov5/detect.py --weights {latest_run}/weights/best.pt --img 640 --source drive/MyDrive/training-ia-test/barco/test/ --data yolov5/data/animal.yaml', shell=True, capture_output=True, text=True)
if latest_run:
    # COMANDO
    result = subprocess.run(f'python yolov5/detect.py --weights {latest_run}/weights/best.pt --img 640 --source drive/MyDrive/training-ia-test/barco/test/ --data yolov5/data/animal.yaml', shell=True, capture_output=True, text=True)
    print(result.stdout)
    print(result.stderr)
else:
    print("Não foi possível encontrar a pasta de treinamento mais recente.")
# Out:
# detect: weights=['yolov5/runs/train/exp9/weights/best.pt'], source=drive/MyDrive/training-ia-test/barco/test/, data=yolov5/data/animal.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-440-gf5ebc52c Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/4 /content/drive/MyDrive/training-ia-test/barco/test/AdobeStock_1146352293_Preview.jpeg: 384x640 1 barco, 33.0ms
# image 2/4 /content/drive/MyDrive/training-ia-test/barco/test/AdobeStock_1418984807_Preview.jpeg: 320x640 1 barco, 34.2ms
# ...
